# %% [markdown]
# <h1>Chapter 2 - Large Language Models</h1>
# <i>Exploring Large Language Model architecture</i>
#
#
# <a href="https://www.amazon.com/Illustrated-Guide-AI-Agents-Concepts/dp/B0GTYL2QSJ"><img src="https://img.shields.io/badge/Buy%20the%20Book!-grey?logo=amazon"></a>
# <a href="https://www.oreilly.com/library/view/an-illustrated-guide/9798341662681/"><img src="https://img.shields.io/badge/O'Reilly-white.svg?logo=..."></a>
# <a href="https://github.com/HandsOnLLM/An-Illustrated-Guide-To-AI-Agents"><img src="https://img.shields.io/badge/GitHub%20Repository-black?logo=github"></a>
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HandsOnLLM/An-Illustrated-Guide-To-AI-Agents/blob/main/chapter02/chapter02.ipynb)
#
# ---
#
# This notebook is for Chapter 2 of [An Illustrated Guide to AI Agents](https://www.amazon.com/Illustrated-Guide-AI-Agents-Concepts/dp/B0GTYL2QSJ) by [Maarten Grootendorst](https://www.linkedin.com/in/mgrootendorst/) and [Jay Alammar](https://www.linkedin.com/in/jalammar).
#
# ---
#
# <a href="https://www.amazon.com/Illustrated-Guide-AI-Agents-Concepts/dp/B0GTYL2QSJ">
# <img src="https://learning.oreilly.com/covers/urn:orm:book:9798341662681/400w/" width="350"/></a>

# %% [markdown]
# ### **[OPTIONAL]** - Installing Packages on Google Colab <img src="https://upload.wikimedia.org/wikipedia/commons/d/d0/Google_Colaboratory_SVG_Logo.svg" width=100>
#
# If you are viewing this notebook on Google Colab (or any other cloud vendor), you need to **uncomment and run** one of the following codeblock to install the dependencies for this chapter. If you want to use a cloud provider, you only need to run the following code block:

# %%
# %%capture
# !pip install illustrated-agents

# %% [markdown]
# ---
#
# 💡 **NOTE**: If you want to use the GPU with `ollama`, then you will have to select a GPU first. In Google Colab, go to
# **Runtime > Change runtime type > Hardware accelerator > GPU > GPU type > T4**.
#
# Then, **uncomment** and run this codeblock:
#
# ---

# %%
# !apt-get install -y zstd > /dev/null 2>&1 && curl -fsSL https://ollama.com/install.sh | sh
# !nohup ollama serve > /dev/null 2>&1 & sleep 3 && ollama pull gemma4:e4b &

# %% [markdown]
# <hr style="height: 5px; border: none; border-radius: 5px; background: linear-gradient(to right, #000000, #7D7D7D);" />

# %% [markdown]
# ## 1- Adding the `"Brain"`
#
# Throughout this chapter, we covered the foundational structure of common LLMs, namely the Transformer. In this accompanying notebook, we will be adding *any* LLM to our `TinyAgent` as our first step towards autonomy.
#
# ![../images/ch2.png](../images/ch2.png)

# %% [markdown]
# To do so, we will have to consider which LLM we want to be using. This decision can be quite complex as it relates to your use case, your hardware (requirements), etc. Instead of providing you a full list of (quickly outdated) LLMs, we instead decided to allow readers to run almost *any* LLM by using the common `OpenAI` endpoint. Most LLMs these days are hosted either locally or online and accessing these servers can be done in many different ways. Most of them, however, expose an `OpenAI` API that allows us to query an LLM always in the same way. Likewise, this allows you to use any LLM whether it is hosted by [`Ollama`](https://ollama.com/), [`vLLM`](https://github.com/vllm-project/vllm) or hosted in the cloud (like Gemini, Claude, and ChatGPT).
#
# Let us explore various LLM inference engines for running your LLM that all create an `OpenAI` endpoint we can query:
#
# ## 2- **Inference Engines**
#
# We split the inference engines by how they are typically used, namely either for local inference on your device on or using the cloud (which often is a proprietary model).
#
# ### **Local**
#
# As big fans of open-weight LLMs, we want users to be able to create and run Agents on their local devices. This setup can be a bit tricky since it requires setting up your environment, CUDA, Transformers, etc. Fortunately, there are a couple of packages that make this much easier.
#
# #### 🔹 **Ollama**
#
# [`Ollama`](https://ollama.com/) is arguably one of the most straightforward methods to run LLMs locally without needing to know much about how to setup your environment or offload layers to your GPU, Ollama does all of that for you and more. You can [download](https://ollama.com/) Ollama from their website. After installation, you can [download any model](https://ollama.com/search) using the following command
#
# ```bash
# # Cannot reason and call tools natively
# ollama pull gemma4:12b
#
# # Has native reasoning and tool calling capabilities
# ollama pull gemma4:e4b
# ```
#
# After downloading the model, you can use the interface of the software to talk to your LLM:
#
# ![../images/ollama.png](../images/ollama.png)
#
# As most local inference engines, it exposes a server with a REST API that we can query to run inference. `LiteLLM` takes care of that for us, so all you have to do is download `ollama` and a model that you want to run (we advise `gemma4:e4b` but more on that later!).
#
# #### 🔹 **LM Studio**
#
# Another popular method is using [`LM Studio`](https://lmstudio.ai/). Like Ollama, `LM Studio` can be downloaded and used to run models locally without having in-depth knowledge about setting up hardware-specific inference. After installing the software you first need to click on the "search" icon so we can begin downloading the model:
#
# ![../images/lmstudio1.png](../images/lmstudio1.png)
#
# Then, search for your model (we are using gemma 4 with 4 billion parameters) and download like so:
#
# ![../images/lmstudio2.png](../images/lmstudio2.png)
#
# Like Ollama, we can use the server endpoint to run our model. To check which address it is using:
#
# ![../images/lmstudio3.png](../images/lmstudio3.png)
#
# **NOTE**: Remember to also download the Gemma 4 E4B model as we will use that for native reasoning and tool calling capabilities.
#
# #### 🔹 **Llama.cpp**
#
# If you have experience with the terminal, Linux, setting up servers, etc. and want to have more control, then we advise the popular [`llama.cpp`](https://github.com/ggml-org/llama.cpp) package. This inference engine runs fully locally but requires you to install it yourself. Fortunately, [installation](https://github.com/ggml-org/llama.cpp/blob/master/docs/install.md) only requires a single line of code:
#
# ```sh
# # Winget (Windows)
# winget install llama.cpp
#
# # Homebrew (Mac and Linux)
# brew install llama.cpp
# ```
#
# This will install `llama.cpp` on your device along with the `llama-server`. The latter is what `LiteLLM` will use to query your model. Before doing so, we first need to download the quantized model. Quantization is essentially a compression of a model's parameters in lower precision, which allows for much smaller models without too much of a drop in performance.
#
# As always, we recommend downloading the 4-bit quantized [Gemma 3](https://huggingface.co/unsloth/gemma-3-12b-it-GGUF/blob/main/gemma-3-12b-it-Q4_K_M.gguf) and [Gemma 4](https://huggingface.co/unsloth/gemma-4-E4B-it-GGUF/blob/main/gemma-4-E4B-it-Q4_K_M.gguf) models.
#
# After doing so, you can start your server up with (for Gemma 3):
#
# ```bash
# llama-server -m .\gemma-3-12b-it-Q4_K_M.gguf --port 8080
# ```
#
# and the following for Gemma 4:
#
# ```bash
# llama-server -m .\gemma-4-E4B-it-Q4_K_M.gguf --port 8080
# ```
#
# The server and UI can then be accessed through your browser: http://localhost:8080
#
# ![../images/llamacpp.png](../images/llamacpp.png)
#
# ### **Cloud**
#
# Although it is nice to run things locally, not everyone has access to powerful hardware capable enough to run these models. Instead, we can use cloud providers and use their (**free!**) tiers to run the Agent(s) throughout this book. Although we want to showcase the evolution of a non-reasoning/tool calling model to a reasoning/tool calling model, these large models are exceptionally strong and we can simply disable their reasoning and tool calling capabilities! So feel free to use a larger model as it should work without any issues throughout all examples.
#
# #### 🔹 **Google**
#
# Google has some amazing models to use (like the Gemini family of models) but also allow you to run their open-weight models (such as Gemma 4), which makes this a very interesting platform to use. We will be using the **Free Tier** which allows us to use some of these models with rate limits. To make sure we do not hit the rate limits, we advise to use their "flash" variants or their open-weight models.
#
# First, go to the [Gemini documentation](https://ai.google.dev/gemini-api/docs/api-key) and click on "Create or view a Gemini API Key":
#
# ![../images/google1.png](../images/google1.png)
#
# Then, click on "Create API Key":
#
# ![../images/google2.png](../images/google2.png)
#
# Before you can actually create a key, you may need to first create a project if you hadn't already done so. Then select it and create the key:
#
# ![../images/google3.png](../images/google3.png)
#
# Finally, copy your API key to use throughout this book.
#
# #### 🔹 **OpenRouter**
#
# [OpenRouter](https://openrouter.ai/) is a unified gateway that lets you call models from many providers (both open weights and proprietary) through a single OpenAI-compatible API. It is useful if you want to switch models without juggling separate keys. You can get an API key [here](https://openrouter.ai/keys); they offer a handful of free models with rate limits and pay-per-token for the rest.
#
# #### 🔹 **OpenAI**
#
# You can also use one of OpenAI's models, which do not have a Free tier unfortunately. That said, if you already happen to have an API Key, you can find it [here](https://platform.openai.com/api-keys) and simply use that for one of their models.
#
# #### 🔹 **Claude**
#
# Although we haven't tried it ourselves yet, free credits are given to new users to test the API. We are not sure whether this is sufficient for testing the entire book, so be aware. You can find more about their pricing [here](https://platform.claude.com/docs/en/about-claude/pricing).
#
# #### 🔹 **Cohere**
#
# [Cohere](https://cohere.com/)'s Command family of models is strong on multilinguality and general tool use. They expose an OpenAI-compatible endpoint and a free trial tier suitable for working through this book. You can get an API key [here](https://dashboard.cohere.com/api-keys).

# %% [markdown]
# ## 3 - **Which model should I use?**
#
# The models that we are going to use throughout this book are Gemma 3 and Gemma 4 variants. As mentioned before, we like to showcase the evolution of these models as that will help you understand what these newer models (like Gemma 4) can "just do". They are trained to perform reasoning and tool calling which takes away some of the intuition behind these techniques.
#
# ![../images/evolution.png](../images/evolution.png)
#
# The Gemma 3 and 4 models come in various sizes.
#
# Gemma 3 has four sizes (1B, 4B, 12B, and 27B) and we have been successfully testing the model with 12 billion parameters (12B) at a quantization (compression) of 4 bits. This model can be run locally if you have 12GB of (V)RAM available. All of these models are great contenders, but if you want more performance than the E4B, we would advise using [27B](https://ollama.com/library/gemma3:27b) instead.
#
# Gemma 4 has four sizes (E2B, E4B, 26B A4B, and 31B) and we have been successfully testing the model with 4 billion parameters (E4B) at a quantization (compression) of 4 bits. This model can be run locally if you have 12GB of (V)RAM available. All of these models are great contenders, but if you want more performance than the E4B, we would advise using [26B A4B](https://ollama.com/library/gemma4:26b) instead.
#
# That said, all examples can be done with a sufficiently capable model! There is no way we are going to limit you to only use specific models. We have implemented all examples so that you can use any model with any server with an `openai` endpoint :)
#
# Although we have not tested all of them, these are models that are at the time of writing (April 2026) considered one of the best in their size category:
#
# * Gemma 4
# * Qwen 3.5
# * GPT-OSS
# * GLM-4.7 Flash
# * Phi-4
#
# Larger, open-weight models include:
#
# * Kimi-K2
# * DeepSeek V3.2

# %% [markdown]
# ## 4 - **The LLM Wrapper**

# %% [markdown]
# We are using OpenAI-compatible endpoints which uses a very specific formatting structure for how the response of the LLM is parsed. It includes standardized fields, parameters, and response fields so that you know you can always get a reply back in the same one. As OpenAI were a major start in this AI-boom, their API has become one of the standards of accessing LLMs that are hosted on servers.
#
# Fortunately, this makes the implementation of your `LLM` rather straightforward. We are going to show `Gemma 4` first since that has additional fields (like `reasoning` and `tool_calls`) to explore. We can use the `messages` structure to talk to the LLM. These `messages` is a common format for structuring multiple turns of question/responses between you (`user`) and the LLM (`assistant`). To ask a question, we use the `user` role:

# %%
import json
import os
import urllib.request

from rich import print

# Prepare request
data = json.dumps(
    {
        "model": "gemma4:e2b",
        "messages": [{"role": "user", "content": "Hi! How's life?"}]
    }
).encode("utf-8")

# Post request (LM Studio, local)
req = urllib.request.Request(
    url="http://localhost:1234/v1/chat/completions",
    data=data,
    headers={"Content-Type": "application/json"}
)

## Or via OpenRouter (cloud). Same request shape; the differences are the URL,
## the model name OpenRouter hosts, and a Bearer token in the Authorization header:
# data = json.dumps(
#     {
#         "model": "google/gemma-4-31b-it",
#         "messages": [{"role": "user", "content": "Hi! How's life?"}]
#     }
# ).encode("utf-8")
# req = urllib.request.Request(
#     url="https://openrouter.ai/api/v1/chat/completions",
#     data=data,
#     headers={
#         "Content-Type": "application/json",
#         "Authorization": f"Bearer {os.environ['OPENROUTER_API_KEY']}",
#     },
# )

# Parse response
with urllib.request.urlopen(req) as response:
    result = json.loads(response.read())

print(result["choices"][0])
# Out:
# {
#     'index': 0,
#     'message': {
#         'role': 'assistant',
#         'content': "Hello! I'm doing well, thank you for asking. As an AI, I don't experience life in the human
# sense, but I am functioning perfectly and ready to assist you.\n\nHow about you? How is your day going?",
#         'reasoning_content': 'Thinking Process:\n\n1.  **Analyze the Request:** The user asked "Hi! How\'s life?"
# This is a casual, conversational greeting/query about well-being.\n2.  **Determine Identity & Role
# (Self-Correction/Context Check):** I am Gemma 4, an LLM. I don\'t have personal feelings, experiences, or a "life"
# in the human sense.\n3.  **Formulate an Appropriate Response Strategy:**\n    *   Acknowledge the greeting
# warmly.\n    *   Explain my nature (as an AI) to manage expectations gently.\n    *   Pivot the conversation back
# to the user (invitation for them to share what\'s going on).\n4.  **Draft the Response (Internal Monologue &
# Refinement):**\n    *   *Initial thought:* I am fine, thank you.\n    *   *Refinement:* Too robotic. Needs more
# conversational flow.\n    *   *Adding context:* Since I don\'t have feelings, I should focus on functioning well.\n
# *   *Engaging the user:* Ask how *they* are doing.\n5.  **Final Output Generation.** (This leads to the generated
# response.)',
#         'tool_calls': []
#     },
#     'logprobs': None,
#     'finish_reason': 'stop'
# }

# %% [markdown]
# In here, you may find, among others:
#
# * `content` -- The main answer of the LLM
# * `reasoning` -- The thinking behavior of the LLM. We explore this in more detail in Chapter 3.
# * `tool_calls` -- These are the tools a model might use (it's not there since it didn't call any tools). We explore this in more detail in Chapter 5.

# %% [markdown]
# When we look what is in this `result["choices"][0]` we can see that it returns a dictionary with a `message` where you can find the answer (`content`) but also whether there was any reasoning (`reasoning`) or tool calls (`tool_calls`). For the purpose of this book, we are not going to be using the tool and reasoning fields immediately! The reason for that is two-fold and is important for the philosophy behind understanding what is happening under the hood.
#
# 1) Using `reasoning` and `tool_calls` is a bit "magical" and does not teach you how these are actually created and used. Instead, we are going to show you how to do this explicitly.
#
# 2) Some models actually do not support `reasoning` and `tool_calls` but with proper prompting can still be used as Agents! So instead of blindly relying on these fields, we want to show you how nudge the model to do explicit reasoning and tool calling with prompting.
#
# That said, of course we are going to show you how to use those fields! It's important to see what is happening under the hood (through prompting) and how that behavior eventually evolved to models being learned how to do this (native `reasoning` and `tool_calls`).
#
# There is a tiny problem though with having three different backends, they all give back responses in slightly different ways! To use all of them, we are going to wrap their answers into a `Response` dataclass where we will track their `content`, `reasoning`, `tool_call`, and other `metadata` the model may provide:

# %%
from dataclasses import dataclass

@dataclass
class Response:
    """Structured response from LLM calls."""

    content: str = ""
    reasoning: str | None = None
    tool_call: dict | None = None
    metadata: dict | None = None

# %% [markdown]
# For now, we are only interested in using the `content` of the model as we want to show you how to have a non-reasoning model still show reasoning traces! To do that, we are adding a parameter to the `LLM` that can disable thinking.

# %%
import json
import urllib.request


class LLM:
    def __init__(
        self,
        model: str,
        base_url: str = "http://localhost:1234/v1",
        api_key: str = "no_key",
        think: bool = False,
        temperature: float | None = None,
    ):
        """Initialize the LLM with the given model."""
        self.model = model
        self.base_url = base_url
        self.api_key = api_key
        self.think = think
        self.temperature = temperature

    def generate(
        self, messages: list[dict], tools: list | None = None
    ) -> Response:
        """Generate a response from the LLM given a list of messages."""
        # Build the request body
        body = {
            "model": self.model,
            "messages": messages,
        }

        # Tools and Reasoning
        if tools:
            body["tools"] = tools
        if not self.think:
            body["reasoning_effort"] = "none"
        else:
            body["reasoning_effort"] = "medium"
        if self.temperature is not None:
            body["temperature"] = self.temperature

        # POST to the OpenAI-compatible /chat/completions endpoint
        request = urllib.request.Request(
            f"{self.base_url}/chat/completions",
            data=json.dumps(body).encode(),
            headers={
                "Content-Type": "application/json",
                "Authorization": f"Bearer {self.api_key}",
            },
        )
        with urllib.request.urlopen(request) as response:
            data = json.loads(response.read())

        # Extract message, tool_call, and metadata
        message = data["choices"][0]["message"]
        reasoning = message.get("reasoning") or message.get("reasoning_content")
        tool_calls = message.get("tool_calls")
        tool_call = tool_calls[0] if tool_calls else None
        metadata = {
            "model": data["model"],
            "prompt_tokens": data["usage"]["prompt_tokens"],
            "completion_tokens": data["usage"]["completion_tokens"],
        }

        # Format as Response dataclass
        return Response(
            content=message.get("content"),
            reasoning=reasoning,
            tool_call=tool_call,
            metadata=metadata,
        )

# %% [markdown]
# Note we are going to skip adding the tool call right now but we will circle back in Chapter 5!

# %% [markdown]
# Let's explore these steps in more detail and let's zoom in a bit on what we did with the `openai` function:

# %%
from illustrated_agents.chapters.ch2 import llm_annotated; llm_annotated
# Out:
# <style>
# pre{line-height:1.5em!important}
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca-099c2583 .hll { background-color: #6e7681 }
# .ca-099c2583 { background: #0d1117; color: #E6EDF3 }
# .ca-099c2583 .c { color: #8B949E; font-style: italic } /* Comment */
# .ca-099c2583 .err { color: #F85149 } /* Error */
# .ca-099c2583 .esc { color: #E6EDF3 } /* Escape */
# .ca-099c2583 .g { color: #E6EDF3 } /* Generic */
# .ca-099c2583 .k { color: #FF7B72 } /* Keyword */
# .ca-099c2583 .l { color: #A5D6FF } /* Literal */
# .ca-099c2583 .n { color: #E6EDF3 } /* Name */
# .ca-099c2583 .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca-099c2583 .x { color: #E6EDF3 } /* Other */
# .ca-099c2583 .p { color: #E6EDF3 } /* Punctuation */
# .ca-099c2583 .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca-099c2583 .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca-099c2583 .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca-099c2583 .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca-099c2583 .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca-099c2583 .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca-099c2583 .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca-099c2583 .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca-099c2583 .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca-099c2583 .gr { color: #FFA198 } /* Generic.Error */
# .ca-099c2583 .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca-099c2583 .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca-099c2583 .go { color: #8B949E } /* Generic.Output */
# .ca-099c2583 .gp { color: #8B949E } /* Generic.Prompt */
# .ca-099c2583 .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca-099c2583 .gu { color: #79C0FF } /* Generic.Subheading */
# .ca-099c2583 .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca-099c2583 .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca-099c2583 .kc { color: #79C0FF } /* Keyword.Constant */
# .ca-099c2583 .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca-099c2583 .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca-099c2583 .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca-099c2583 .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca-099c2583 .kt { color: #FF7B72 } /* Keyword.Type */
# .ca-099c2583 .ld { color: #79C0FF } /* Literal.Date */
# .ca-099c2583 .m { color: #A5D6FF } /* Literal.Number */
# .ca-099c2583 .s { color: #A5D6FF } /* Literal.String */
# .ca-099c2583 .na { color: #E6EDF3 } /* Name.Attribute */
# .ca-099c2583 .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca-099c2583 .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca-099c2583 .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca-099c2583 .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca-099c2583 .ni { color: #FFA657 } /* Name.Entity */
# .ca-099c2583 .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca-099c2583 .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca-099c2583 .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca-099c2583 .nn { color: #FF7B72 } /* Name.Namespace */
# .ca-099c2583 .nx { color: #E6EDF3 } /* Name.Other */
# .ca-099c2583 .py { color: #79C0FF } /* Name.Property */
# .ca-099c2583 .nt { color: #7EE787 } /* Name.Tag */
# .ca-099c2583 .nv { color: #79C0FF } /* Name.Variable */
# .ca-099c2583 .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca-099c2583 .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca-099c2583 .w { color: #6E7681 } /* Text.Whitespace */
# .ca-099c2583 .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca-099c2583 .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca-099c2583 .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca-099c2583 .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca-099c2583 .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca-099c2583 .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca-099c2583 .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca-099c2583 .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca-099c2583 .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca-099c2583 .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca-099c2583 .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca-099c2583 .se { color: #79C0FF } /* Literal.String.Escape */
# .ca-099c2583 .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca-099c2583 .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca-099c2583 .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca-099c2583 .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca-099c2583 .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca-099c2583 .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca-099c2583 .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca-099c2583 .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca-099c2583 .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca-099c2583 .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca-099c2583 .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca-099c2583 .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca-099c2583 .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca-099c2583{background:#0d1117!important;color:#e6edf3!important;font-size:14px}
# .ca-099c2583 pre{margin:0;padding:0;line-height:1.5em!important;background:#0d1117!important;color:#e6edf3!important}
# .ca-099c2583 code{background:#0d1117!important;color:#e6edf3!important}
# .ca-099c2583 .hll{background:#3d4626!important;display:block;width:100%}
# .ca-099c2583 .linenos{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div style="display:inline-flex;align-items:flex-start;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace;font-size:14px;line-height:1.5em">
# <div style="flex:3;overflow-x:auto;background:#0d1117"><div class="ca-099c2583"><pre><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="nf">generate</span><span class="p">(</span>
# <span class="linenos"> 2</span>    <span class="bp">self</span><span class="p">,</span> <span class="n">messages</span><span class="p">:</span> <span class="nb">list</span><span class="p">[</span><span class="nb">dict</span><span class="p">],</span> <span class="n">tools</span><span class="p">:</span> <span class="nb">list</span> <span class="o">|</span> <span class="kc">None</span> <span class="o">=</span> <span class="kc">None</span>
# <span class="linenos"> 3</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="n">Response</span><span class="p">:</span>
# <span class="linenos"> 4</span><span class="w">    </span><span class="sd">"""Generate a response from the LLM given a list of messages."""</span>
# <span class="linenos"> 5</span>    <span class="c1"># Build the request body</span>
# <span class="linenos"> 6</span>    <span class="n">body</span> <span class="o">=</span> <span class="p">{</span>
# <span class="linenos"> 7</span>        <span class="s2">"model"</span><span class="p">:</span> <span class="bp">self</span><span class="o">.</span><span class="n">model</span><span class="p">,</span>
# <span class="linenos"> 8</span>        <span class="s2">"messages"</span><span class="p">:</span> <span class="n">messages</span><span class="p">,</span>
# <span class="linenos"> 9</span>    <span class="p">}</span>
# <span class="linenos">10</span>
# <span class="linenos">11</span>    <span class="c1"># Tools and Reaso

# %% [markdown]
# Finally, we can call the LLM with our updated class and extract the response only:

# %%
# Re-initialize the LLM with the updated class
llm = LLM(model="gemma4:e2b", think=False)

## Or via OpenRouter (cloud):
# import os
# llm = LLM(
#     model="google/gemma-4-31b-it",
#     base_url="https://openrouter.ai/api/v1",
#     api_key=os.environ["OPENROUTER_API_KEY"],
#     think=False,
# )

# Generate a `Response` dataclass
response = llm.generate([{"role": "user", "content": "Hi! How's life?"}])
print(response)
# Out:
# Response(
#     content="Hi! Life is going well, thank you for asking. I'm currently busy processing information and ready to
# help you with whatever you need.\n\nHow about **you**? How is life treating you today? 😊",
#     reasoning='',
#     tool_call=None,
#     metadata={'model': 'google/gemma-4-e2b', 'prompt_tokens': 16, 'completion_tokens': 45}
# )

# %% [markdown]
# We have disabled reasoning for Gemma 4 E4B. However, these models shine when reasoning is enabled. Instead of trying to limit this model, we are going to use Gemma 3 12B throughout all prompting-based examples instead. For the purpose of this book, we believe it is much more interesting to enhance a model rather than try to limit it. That said, if you want to use a more capable model throughout this book, you can! Just make sure to disable thinking as we are going to try to enable that through prompting.
#
# Note that in the end we are working towards native tool calling and reasoning, so no prompt-based techniques. As such, we hope to show you this evolution from prompt-based techniques to native agentic capabilities!

# %% [markdown]
# ## 5 - The `Trajectory`

# %% [markdown]
# Before we explore how to update your `agent.py`, there is something else to explore first. A vital component of Agentic Harnesses (which is the framework that we are creating) is making sure you can easily debug what is happening. An Agent might run for several turns at a time and run into an incorrect tool usage. To easily debug that we want to keep track of everything the model has done so far. To do that, we track each `Step` the agent has taken (including `observation` from the output of a tool):

# %%
from dataclasses import dataclass

@dataclass
class Step:
    """A single step in an agent's trajectory."""

    thought: str = ""
    action: dict | None = None
    observation: str | None = None
    answer: str | None = None
    metadata: dict | None = None

# %% [markdown]
# Note that `Step` is very much like the `Response` object that we saw before but with a couple of additional fields, namely `answer` and `observation`. The `answer` is the final answer of the model and represents that the Agent has reached the end of its turn. The `observation` is the output of tool usage. For example, it can search the web for information about flamingos and get returned a bunch of information (`observation`). Finally, instead of having a `tool_call` field, we now use `action`. This is on purpose as it is part of the THOUGHT/ACTION/OBSERVATION loop that we will explore in Chapter 6.

# %% [markdown]
# An Agent might need various steps to get to a final answer and use many different actions to reach that call. All these steps together is what we call an Agent's `Trajectory`. We want to make sure we can easily track that information. The `Trajectory` of your Agent is as follows and allows you to add your query with `initialize` and add a full step with `add` where the potential reasoning, action, observation, answer, and metadata is tracked:

# %%
class Trajectory:
    """Records agent execution as a sequence of runs."""
    def __init__(self) -> None:
        self.runs: list[dict] = []

    def initialize(self, query: str) -> None:
        """Register a new run with the given query."""
        self.runs.append({"query": query, "steps": []})

    def add(self, response: Response, observation: str | None = None) -> None:
        """Record a step from a Response, optionally with an observation."""
        # Add THOUGHT
        step = Step(
            thought=response.reasoning or "",
            metadata=response.metadata,
        )

        # Add ACTION/OBSERVATION or ANSWER
        if observation is not None:
            step.action = response.tool_call
            step.observation = observation
        else:
            step.answer = response.content
            
        self.runs[-1]["steps"].append(step)

# %% [markdown]
# The trajectory is meant only to track a `Step` easily:

# %%
from illustrated_agents.chapters.ch2 import trajectory_add_annotated; trajectory_add_annotated
# Out:
# <style>
# pre{line-height:1.5em!important}
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .ca-cd8928c8 .hll { background-color: #6e7681 }
# .ca-cd8928c8 { background: #0d1117; color: #E6EDF3 }
# .ca-cd8928c8 .c { color: #8B949E; font-style: italic } /* Comment */
# .ca-cd8928c8 .err { color: #F85149 } /* Error */
# .ca-cd8928c8 .esc { color: #E6EDF3 } /* Escape */
# .ca-cd8928c8 .g { color: #E6EDF3 } /* Generic */
# .ca-cd8928c8 .k { color: #FF7B72 } /* Keyword */
# .ca-cd8928c8 .l { color: #A5D6FF } /* Literal */
# .ca-cd8928c8 .n { color: #E6EDF3 } /* Name */
# .ca-cd8928c8 .o { color: #FF7B72; font-weight: bold } /* Operator */
# .ca-cd8928c8 .x { color: #E6EDF3 } /* Other */
# .ca-cd8928c8 .p { color: #E6EDF3 } /* Punctuation */
# .ca-cd8928c8 .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .ca-cd8928c8 .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .ca-cd8928c8 .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .ca-cd8928c8 .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .ca-cd8928c8 .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .ca-cd8928c8 .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .ca-cd8928c8 .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .ca-cd8928c8 .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .ca-cd8928c8 .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .ca-cd8928c8 .gr { color: #FFA198 } /* Generic.Error */
# .ca-cd8928c8 .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .ca-cd8928c8 .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .ca-cd8928c8 .go { color: #8B949E } /* Generic.Output */
# .ca-cd8928c8 .gp { color: #8B949E } /* Generic.Prompt */
# .ca-cd8928c8 .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .ca-cd8928c8 .gu { color: #79C0FF } /* Generic.Subheading */
# .ca-cd8928c8 .gt { color: #FF7B72 } /* Generic.Traceback */
# .ca-cd8928c8 .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .ca-cd8928c8 .kc { color: #79C0FF } /* Keyword.Constant */
# .ca-cd8928c8 .kd { color: #FF7B72 } /* Keyword.Declaration */
# .ca-cd8928c8 .kn { color: #FF7B72 } /* Keyword.Namespace */
# .ca-cd8928c8 .kp { color: #79C0FF } /* Keyword.Pseudo */
# .ca-cd8928c8 .kr { color: #FF7B72 } /* Keyword.Reserved */
# .ca-cd8928c8 .kt { color: #FF7B72 } /* Keyword.Type */
# .ca-cd8928c8 .ld { color: #79C0FF } /* Literal.Date */
# .ca-cd8928c8 .m { color: #A5D6FF } /* Literal.Number */
# .ca-cd8928c8 .s { color: #A5D6FF } /* Literal.String */
# .ca-cd8928c8 .na { color: #E6EDF3 } /* Name.Attribute */
# .ca-cd8928c8 .nb { color: #E6EDF3 } /* Name.Builtin */
# .ca-cd8928c8 .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .ca-cd8928c8 .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .ca-cd8928c8 .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .ca-cd8928c8 .ni { color: #FFA657 } /* Name.Entity */
# .ca-cd8928c8 .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .ca-cd8928c8 .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .ca-cd8928c8 .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .ca-cd8928c8 .nn { color: #FF7B72 } /* Name.Namespace */
# .ca-cd8928c8 .nx { color: #E6EDF3 } /* Name.Other */
# .ca-cd8928c8 .py { color: #79C0FF } /* Name.Property */
# .ca-cd8928c8 .nt { color: #7EE787 } /* Name.Tag */
# .ca-cd8928c8 .nv { color: #79C0FF } /* Name.Variable */
# .ca-cd8928c8 .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .ca-cd8928c8 .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .ca-cd8928c8 .w { color: #6E7681 } /* Text.Whitespace */
# .ca-cd8928c8 .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .ca-cd8928c8 .mf { color: #A5D6FF } /* Literal.Number.Float */
# .ca-cd8928c8 .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .ca-cd8928c8 .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .ca-cd8928c8 .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .ca-cd8928c8 .sa { color: #79C0FF } /* Literal.String.Affix */
# .ca-cd8928c8 .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .ca-cd8928c8 .sc { color: #A5D6FF } /* Literal.String.Char */
# .ca-cd8928c8 .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .ca-cd8928c8 .sd { color: #A5D6FF } /* Literal.String.Doc */
# .ca-cd8928c8 .s2 { color: #A5D6FF } /* Literal.String.Double */
# .ca-cd8928c8 .se { color: #79C0FF } /* Literal.String.Escape */
# .ca-cd8928c8 .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .ca-cd8928c8 .si { color: #A5D6FF } /* Literal.String.Interpol */
# .ca-cd8928c8 .sx { color: #A5D6FF } /* Literal.String.Other */
# .ca-cd8928c8 .sr { color: #79C0FF } /* Literal.String.Regex */
# .ca-cd8928c8 .s1 { color: #A5D6FF } /* Literal.String.Single */
# .ca-cd8928c8 .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .ca-cd8928c8 .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .ca-cd8928c8 .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .ca-cd8928c8 .vc { color: #79C0FF } /* Name.Variable.Class */
# .ca-cd8928c8 .vg { color: #79C0FF } /* Name.Variable.Global */
# .ca-cd8928c8 .vi { color: #79C0FF } /* Name.Variable.Instance */
# .ca-cd8928c8 .vm { color: #79C0FF } /* Name.Variable.Magic */
# .ca-cd8928c8 .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .ca-cd8928c8{background:#0d1117!important;color:#e6edf3!important;font-size:14px}
# .ca-cd8928c8 pre{margin:0;padding:0;line-height:1.5em!important;background:#0d1117!important;color:#e6edf3!important}
# .ca-cd8928c8 code{background:#0d1117!important;color:#e6edf3!important}
# .ca-cd8928c8 .hll{background:#3d4626!important;display:block;width:100%}
# .ca-cd8928c8 .linenos{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div style="display:inline-flex;align-items:flex-start;background:#0d1117;border-radius:8px;border:1px solid #444;margin:10px 0;font-family:monospace;font-size:14px;line-height:1.5em">
# <div style="flex:3;overflow-x:auto;background:#0d1117"><div class="ca-cd8928c8"><pre><span class="linenos"> 1</span><span class="k">def</span><span class="w"> </span><span class="nf">add</span><span class="p">(</span><span class="bp">self</span><span class="p">,</span> <span class="n">response</span><span class="p">:</span> <span class="n">Response</span><span class="p">,</span> <span class="n">observation</span><span class="p">:</span> <span class="nb">str</span> <span class="o">|</span> <span class="kc">None</span> <span class="o">=</span> <span class="kc">None</span><span class="p">)</span> <span class="o">-&gt;</span> <span class="kc">None</span><span class="p">:</span>
# <span class="linenos"> 2</span><span class="w">    </span><span class="sd">"""Record a step from a Response, optionally with an observation."""</span>
# <span class="linenos"> 3</span>    <span class="c1"># Add THOUGHT</span>
# <span class="hll"><span class="linenos"> 4</span>    <span class="n">step</span> <span class="o">=</span> <span class="n">Step</span><span class="p">(</span>
# </span><span class="hll"><span class="linenos"> 5</span>        <span class="n">thought</span><span class="o">=</span><span class="n">response</span><span class="o">.</span><span class="n">reasoning</span> <span class="ow">or</span> <span class="s2">""</span><span class="p">,</span>
# </span><span class="hll"><span class="linenos"> 6</span>        <span class="n">metadata</span><span class="o">=</span><span class="n">response</span><span class="o">.</span><span class="n">metadata</span><span class="p">,</span>
# </span><span class="hll"><span class="linenos"> 7</span>    <span class="p">)</span>

# %% [markdown]
# ## 6 - Updating `agent.py`
#
# We update our `TinyAgent` to have a brain and actually be able to answer:

# %%
class TinyAgent:
    """A minimal, modular, and educational agent framework."""

    def __init__(self, llm: LLM):
        self.llm = llm
        self.memory = None  # Chapter 4: Add Memory
        self.tools = None  # Chapter 5: Add Tools
        self.planner = None  # Chapter 6: Add Planning

        self.trajectory = Trajectory()

    def run(self, task: str) -> str:
        """Run the agent on a task."""
        self.trajectory.initialize(task)
        return self._step(task)

    def _step(self, task: str) -> str:
        """Perform a single step."""
        messages = [{"role": "user", "content": task}]
        response = self.llm.generate(messages)
        self.trajectory.add(response)
        return response.content

    def _execute_action(self, action: str) -> str | None:
        """Execute a tool action."""
        # Placeholder - will be implemented in later chapters
        return f"Executed action: {action}"

# %% [markdown]
# Here is a nicer overview of the changes that we made to `agent.py` (red is removed and green is added code):

# %%
from illustrated_agents.chapters.ch2 import tinyagents_diff; tinyagents_diff
# Out:
# <style>
# pre { line-height: 125%; }
# td.linenos .normal { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #6e7681; background-color: #0d1117; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #e6edf3; background-color: #6e7681; padding-left: 5px; padding-right: 5px; }
# .dv-03533500 .hll { background-color: #6e7681 }
# .dv-03533500 { background: #0d1117; color: #E6EDF3 }
# .dv-03533500 .c { color: #8B949E; font-style: italic } /* Comment */
# .dv-03533500 .err { color: #F85149 } /* Error */
# .dv-03533500 .esc { color: #E6EDF3 } /* Escape */
# .dv-03533500 .g { color: #E6EDF3 } /* Generic */
# .dv-03533500 .k { color: #FF7B72 } /* Keyword */
# .dv-03533500 .l { color: #A5D6FF } /* Literal */
# .dv-03533500 .n { color: #E6EDF3 } /* Name */
# .dv-03533500 .o { color: #FF7B72; font-weight: bold } /* Operator */
# .dv-03533500 .x { color: #E6EDF3 } /* Other */
# .dv-03533500 .p { color: #E6EDF3 } /* Punctuation */
# .dv-03533500 .ch { color: #8B949E; font-style: italic } /* Comment.Hashbang */
# .dv-03533500 .cm { color: #8B949E; font-style: italic } /* Comment.Multiline */
# .dv-03533500 .cp { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Preproc */
# .dv-03533500 .cpf { color: #8B949E; font-style: italic } /* Comment.PreprocFile */
# .dv-03533500 .c1 { color: #8B949E; font-style: italic } /* Comment.Single */
# .dv-03533500 .cs { color: #8B949E; font-weight: bold; font-style: italic } /* Comment.Special */
# .dv-03533500 .gd { color: #FFA198; background-color: #490202 } /* Generic.Deleted */
# .dv-03533500 .ge { color: #E6EDF3; font-style: italic } /* Generic.Emph */
# .dv-03533500 .ges { color: #E6EDF3; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .dv-03533500 .gr { color: #FFA198 } /* Generic.Error */
# .dv-03533500 .gh { color: #79C0FF; font-weight: bold } /* Generic.Heading */
# .dv-03533500 .gi { color: #56D364; background-color: #0F5323 } /* Generic.Inserted */
# .dv-03533500 .go { color: #8B949E } /* Generic.Output */
# .dv-03533500 .gp { color: #8B949E } /* Generic.Prompt */
# .dv-03533500 .gs { color: #E6EDF3; font-weight: bold } /* Generic.Strong */
# .dv-03533500 .gu { color: #79C0FF } /* Generic.Subheading */
# .dv-03533500 .gt { color: #FF7B72 } /* Generic.Traceback */
# .dv-03533500 .g-Underline { color: #E6EDF3; text-decoration: underline } /* Generic.Underline */
# .dv-03533500 .kc { color: #79C0FF } /* Keyword.Constant */
# .dv-03533500 .kd { color: #FF7B72 } /* Keyword.Declaration */
# .dv-03533500 .kn { color: #FF7B72 } /* Keyword.Namespace */
# .dv-03533500 .kp { color: #79C0FF } /* Keyword.Pseudo */
# .dv-03533500 .kr { color: #FF7B72 } /* Keyword.Reserved */
# .dv-03533500 .kt { color: #FF7B72 } /* Keyword.Type */
# .dv-03533500 .ld { color: #79C0FF } /* Literal.Date */
# .dv-03533500 .m { color: #A5D6FF } /* Literal.Number */
# .dv-03533500 .s { color: #A5D6FF } /* Literal.String */
# .dv-03533500 .na { color: #E6EDF3 } /* Name.Attribute */
# .dv-03533500 .nb { color: #E6EDF3 } /* Name.Builtin */
# .dv-03533500 .nc { color: #F0883E; font-weight: bold } /* Name.Class */
# .dv-03533500 .no { color: #79C0FF; font-weight: bold } /* Name.Constant */
# .dv-03533500 .nd { color: #D2A8FF; font-weight: bold } /* Name.Decorator */
# .dv-03533500 .ni { color: #FFA657 } /* Name.Entity */
# .dv-03533500 .ne { color: #F0883E; font-weight: bold } /* Name.Exception */
# .dv-03533500 .nf { color: #D2A8FF; font-weight: bold } /* Name.Function */
# .dv-03533500 .nl { color: #79C0FF; font-weight: bold } /* Name.Label */
# .dv-03533500 .nn { color: #FF7B72 } /* Name.Namespace */
# .dv-03533500 .nx { color: #E6EDF3 } /* Name.Other */
# .dv-03533500 .py { color: #79C0FF } /* Name.Property */
# .dv-03533500 .nt { color: #7EE787 } /* Name.Tag */
# .dv-03533500 .nv { color: #79C0FF } /* Name.Variable */
# .dv-03533500 .ow { color: #FF7B72; font-weight: bold } /* Operator.Word */
# .dv-03533500 .pm { color: #E6EDF3 } /* Punctuation.Marker */
# .dv-03533500 .w { color: #6E7681 } /* Text.Whitespace */
# .dv-03533500 .mb { color: #A5D6FF } /* Literal.Number.Bin */
# .dv-03533500 .mf { color: #A5D6FF } /* Literal.Number.Float */
# .dv-03533500 .mh { color: #A5D6FF } /* Literal.Number.Hex */
# .dv-03533500 .mi { color: #A5D6FF } /* Literal.Number.Integer */
# .dv-03533500 .mo { color: #A5D6FF } /* Literal.Number.Oct */
# .dv-03533500 .sa { color: #79C0FF } /* Literal.String.Affix */
# .dv-03533500 .sb { color: #A5D6FF } /* Literal.String.Backtick */
# .dv-03533500 .sc { color: #A5D6FF } /* Literal.String.Char */
# .dv-03533500 .dl { color: #79C0FF } /* Literal.String.Delimiter */
# .dv-03533500 .sd { color: #A5D6FF } /* Literal.String.Doc */
# .dv-03533500 .s2 { color: #A5D6FF } /* Literal.String.Double */
# .dv-03533500 .se { color: #79C0FF } /* Literal.String.Escape */
# .dv-03533500 .sh { color: #79C0FF } /* Literal.String.Heredoc */
# .dv-03533500 .si { color: #A5D6FF } /* Literal.String.Interpol */
# .dv-03533500 .sx { color: #A5D6FF } /* Literal.String.Other */
# .dv-03533500 .sr { color: #79C0FF } /* Literal.String.Regex */
# .dv-03533500 .s1 { color: #A5D6FF } /* Literal.String.Single */
# .dv-03533500 .ss { color: #A5D6FF } /* Literal.String.Symbol */
# .dv-03533500 .bp { color: #E6EDF3 } /* Name.Builtin.Pseudo */
# .dv-03533500 .fm { color: #D2A8FF; font-weight: bold } /* Name.Function.Magic */
# .dv-03533500 .vc { color: #79C0FF } /* Name.Variable.Class */
# .dv-03533500 .vg { color: #79C0FF } /* Name.Variable.Global */
# .dv-03533500 .vi { color: #79C0FF } /* Name.Variable.Instance */
# .dv-03533500 .vm { color: #79C0FF } /* Name.Variable.Magic */
# .dv-03533500 .il { color: #A5D6FF } /* Literal.Number.Integer.Long */
# .dv-03533500{background:#0d1117!important;color:#e6edf3!important;font-size:14px;line-height:1.4;border-radius:8px;padding:12px;overflow-x:auto}
# .dv-03533500 pre{background:#0d1117!important;color:#e6edf3!important;margin:0}
# .dv-03533500 code{background:#0d1117!important;color:#e6edf3!important}
# </style>
# <div class="dv-03533500"><pre><span></span><span class="gd">--- ch1.TinyAgent</span>
# <span class="gi">+++ ch2.TinyAgent</span>
# <span class="gu">@@ -1,20 +1,25 @@</span>
# <span class="w"> </span>class TinyAgent:
# <span class="w"> </span>    """A minimal, modular, and educational agent framework."""
# <span class="w"> </span>
# <span class="gd">-    def __init__(self):</span>
# <span class="gd">-        self.llm = None  # Chapter 2 &amp; 3: Add LLM</span>
# <span class="gi">+    def __init__(self, llm: LLM):</span>
# <span class="gi">+        self.llm = llm</span>
# <span class="w"> </span>        self.memory = None  # Chapter 4: Add Memory
# <span class="w"> </span>        self.tools = None  # Chapter 5: Add Tools
# <span class="w"> </span>        self.planner = None  # Chapter 6: Add Planning
# <span class="w"> </span>
# <span class="gi">+        self.trajectory = Trajectory()</span>
# <span class="gi">+</span>
# <span class="w"> </span>    def run(self, task: str) -&gt; str:
# <span class="w"> </span>        """Run the agent on a task."""
# <span class="gi">+        self.trajectory.initialize(task)</span>
# <span class="w"> </span>        return self._step(task)
# <span class="w"> </span>
# <span class="w"> </span>    def _step(self, task: str) -&gt; str:
# <span class="w"> </span>        """Perform a single step."""
# <span class="gd">-        # Placeholder - will be implemented in later chapters</span>
# <span class="gd">-        return f"Received: {task}"</span>
# <span class="gi">+        messages = [{"role": "user", "content": task}]</span>
# <span class="gi">+        response = self.llm.generate(messages)</span>
# <span class="gi">+        self.trajectory.add(response)</span>
# <span class="gi">+        return response.content</span>
# <span class="w"> </span>
# <span class="w"> </span>    def _execute_action(self, action: str) -&gt; str:
# <span class="w"> </span>        """Execute a tool action."""
# </pre></div>

# %% [markdown]
# We can then run our agent as follows:

# %%
agent = TinyAgent(llm=llm)
response = agent.run("What is 2 + 2?")
print(response)
# Out:
# $2 + 2 = 4$

# %% [markdown]
# Great, it gives back an answer! Throughout these chapters we also will be looking at the `Trajectory` quite often to debug and see if the `TinyAgent` did as expected. We can access the full trajectory with:

# %%
from rich import print

print(agent.trajectory.runs)
# Out:
# [
#     {
#         'query': 'What is 2 + 2?',
#         'steps': [
#             Step(
#                 thought='',
#                 action=None,
#                 observation=None,
#                 answer='$2 + 2 = 4$',
#                 metadata={'model': 'google/gemma-4-e2b', 'prompt_tokens': 17, 'completion_tokens': 10}
#             )
#         ]
#     }
# ]

# %% [markdown]
# Note though that this can get large quite quickly if we have dozens of tool calls, long reasoning, and more! So, we decided to create a small helper class that visualizes these components. This `TrajectoryViewer` uses basic HTML to gives a bit more control over the what we see and don't see in the Trajectory. After you run the cell, you can click on each run and step block to see same information as above, just a bit more interactive:

# %%
from illustrated_agents.utils import TrajectoryViewer
TrajectoryViewer(agent.trajectory)
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .highlight .hll { background-color: #ffffcc }
# .highlight { background: #f8f8f8; }
# .highlight .c { color: #3D7B7B; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #F00 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666 } /* Operator */
# .highlight .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #9C6500 } /* Comment.Preproc */
# .highlight .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .ges { font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# .highlight .gr { color: #E40000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #008400 } /* Generic.Inserted */
# .highlight .go { color: #717171 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #04D } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #687822 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #00F; font-weight: bold } /* Name.Class */
# .highlight .no { color: #800 } /* Name.Constant */
# .highlight .nd { color: #A2F } /* Name.Decorator */
# .highlight .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #00F } /* Name.Function */
# .highlight .nl { color: #767600 } /* Name.Label */
# .highlight .nn { color: #00F; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #A2F; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #BBB } /* Text.Whitespace */
# .highlight .mb { color: #666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666 } /* Literal.Number.Float */
# .highlight .mh { color: #666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #A45A77 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #00F } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666 } /* Literal.Number.Integer.Long */
#     .trajectory details { margin: 6px 0; border: 1px solid #e4e4e7; border-radius: 6px; }
#     .trajectory summary { cursor: pointer; padding: 8px 12px; font-weight: 500; background: #fafafa; }
#     .trajectory summary .kind { color: #71717a; font-weight: 400; margin-left: 6px; }
#     .trajectory .run > summary { background: #eef2ff; }
#     .trajectory .steps { margin-left: 20px; }
#     .trajectory .field { padding: 8px 12px; }
#     .trajectory .label { color: #52525b; font-size: 0.8em; font-weight: 700; text-transform: uppercase; letter-spacing: 0.06em; margin-bottom: 4px; }
#     .trajectory pre { margin: 0; white-space: pre-wrap; font-family: ui-monospace, monospace; font-size: 0.9em; }
#     .trajectory .highlight { background: transparent; font-size: 0.9em; }
#     </style><div class='trajectory'><details class='run'><summary>Run 1 <span class='kind'>· User query</span></summary><div class='field'><pre>What is 2 + 2?</pre></div></details><div class='steps'><details><summary>Step 1 <span class='kind'>· Final answer</span></summary><div class='field'><div class='label'>answer</div><pre>$2 + 2 = 4$</pre></div>
# <div class='field'><div class='label'>metadata</div><div class='highlight'><span class="p">{</span>
# <span class="w">  </span><span class="nt">"model"</span><span class="p">:</span><span class="w"> </span><span class="s2">"google/gemma-4-e2b"</span><span class="p">,</span>
# <span class="w">  </span><span class="nt">"prompt_tokens"</span><span class="p">:</span><span class="w"> </span><span class="mi">17</span><span class="p">,</span>
# <span class="w">  </span><span class="nt">"completion_tokens"</span><span class="p">:</span><span class="w"> </span><span class="mi">10</span>
# <span class="p">}</span>
# </div></div></details></div></div>

# %% [markdown]
# Our "Agent" is still nothing more than the LLM and has no additional behavior/capabilities that we can showcase yet. For that, we need to add more modules, such as **reasoning** (Chapter 3), **memory** (Chapter 4), **tools** (Chapter 5), and **planning** (Chapter 6).

# %% [markdown]
# ---
#
# ⚠️ **IMPORTANT**: LLMs are stochastic and will not always produce the same output. So it might happen, especially with smaller models, that you do not get the output you are looking for in the examples throughout the book. They are efficient and small examples, so you can simply rerun the examples once and twice and it should work. Note that larger models, like Gemini 3, are unlikely to have that problem since they are quite adept.
#
# ---

# %% [markdown]
# <hr style="height: 5px; border: none; border-radius: 5px; background: linear-gradient(to right, #000000, #7D7D7D);" />

# %% [markdown]
# # What We Built
#
# In this chapter, we covered the basic steps in querying an LLM, what it outputs and how you could connect it to your `TinyAgent`.

# %%
from illustrated_agents.chapters.ch2 import what_we_built; what_we_built
# Out:
# ╭───────────────────────────────────────────────── What We Built ─────────────────────────────────────────────────╮
# │ TinyAgent                                                                                                       │
# │ ├── agent.py      ← Updated (Integrated the `LLM` into your `TinyAgent`)                                        │
# │ ├── llm.py        ← New (An LLM wrapper for local or cloud models.)                                             │
# │ └── trajectory.py ← New (A structured way to record agent execution.)                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# # What's Next
#
# In the next chapter, we will explore how reasoning works from the perspective of both prompting and native reasoning.
